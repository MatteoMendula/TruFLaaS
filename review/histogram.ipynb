# %%
df = pd.read_pickle("./data/df.pkl")
df["type"].value_counts()

print(list(df["type"].value_counts()))

data = {}
keys = df["type"].value_counts().keys()
values = list(df["type"].value_counts())

for i, k in enumerate(keys):
    data[k] = df["type"].value_counts()[k]

print(df["type"].value_counts())

data
# Out:
# [156248, 104510, 104011, 96781, 65746, 62154, 61380, 60554, 56681, 30898, 29297]
# mirai_udp         156248
# gafgyt_tcp        104510
# gafgyt_udp        104011
# mirai_scan         96781
# mirai_syn          65746
# benign             62154
# gafgyt_combo       61380
# mirai_ack          60554
# mirai_udpplain     56681
# gafgyt_junk        30898
# gafgyt_scan        29297
# Name: type, dtype: int64
# {'mirai_udp': 156248,
#  'gafgyt_tcp': 104510,
#  'gafgyt_udp': 104011,
#  'mirai_scan': 96781,
#  'mirai_syn': 65746,
#  'benign': 62154,
#  'gafgyt_combo': 61380,
#  'mirai_ack': 60554,
#  'mirai_udpplain': 56681,
#  'gafgyt_junk': 30898,
#  'gafgyt_scan': 29297}

# %%
from matplotlib import pyplot as plt

plt.title("Class Distribution")
df.groupby("type").size().plot(kind='pie', autopct='%.2f', figsize=(20,10))
# Out:
# <Axes: title={'center': 'Class Distribution'}, ylabel='None'>

# %%
import matplotlib.pyplot as plt
import numpy as np

# Fixing random state for reproducibility
np.random.seed(19680801)


plt.rcdefaults()
fig, ax = plt.subplots()

# Example data
people = ('Tom', 'Dick', 'Harry', 'Slim', 'Jim')
y_pos = np.arange(len(people))
print(y_pos)
performance = 3 + 10 * np.random.rand(len(people))
error = np.random.rand(len(people))

print(performance)

ax.barh(y_pos, performance, xerr=error, align='center')
ax.set_yticks(y_pos, labels=people)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Performance')
ax.set_title('How fast do you want to go today?')

plt.show()
# Out:
# [0 1 2 3 4]
# [10.00367304 10.42750809 10.09280011  8.66745522 12.77785333]

# %%
plt.rcdefaults()
fig, ax = plt.subplots()

print(keys)

y_pos = range(len(keys))
barlist = ax.barh(y_pos, values, align='center')
ax.set_yticks(y_pos, labels=keys)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Counter')
ax.set_title('N-BaIoT dataset')
barlist[len(keys)-2].set_color('#388E3C')
barlist[len(keys)-1].set_color('#388E3C')

plt.show()
# Out:
# Index(['mirai_udp', 'gafgyt_tcp', 'gafgyt_udp', 'mirai_scan', 'mirai_syn',
#        'benign', 'gafgyt_combo', 'mirai_ack', 'mirai_udpplain', 'gafgyt_junk',
#        'gafgyt_scan'],
#       dtype='object')
