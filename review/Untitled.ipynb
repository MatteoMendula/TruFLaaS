# %%
data = {'NO_SELECTION': {'loss': [2.343024, 3], 'accuracy': [0.1743595006398957], 'precision': [0.0], 'recall': [0.0], 'f1': [0.0], 'best_global_accuracy': 0}, 
        'TRUFLAAS': {'loss': [2.355744, 4], 'accuracy': [0.18462197860575183], 'precision': [0.0], 'recall': [0.0], 'f1': [0.0], 'best_global_accuracy': 0}, 
        'TRUSTFED': {'loss': [2.404671, 7], 'accuracy': [0.06843261777702654], 'precision': [0.10948849], 'recall': [0.068432614], 'f1': [0.08422361], 'best_global_accuracy': 0}}
experiment_name = "exp1"
special_clients = "1"
testing_metrics = ["loss", "accuracy", "precision", "recall", "f1"]

# %%
import matplotlib.pyplot as plt
def save_graphs(dict_of_metrics, experiment_name, special_clients):
   
    case_name = "reduced_{}".format(str(special_clients))
    colors = {
        "TRUFLAAS": "red",
        "TRUSTFED": "blue",
        "NO_SELECTION": "green"
    }
    
    for metric in testing_metrics:
        plt.clf()
        for case in dict_of_metrics.keys():
            # case = "TRUFLAAS"/"TRUSTFED"/"NO_SELECTION"
            print(dict_of_metrics[case][metric])
            plt.plot(dict_of_metrics[case][metric], label="{}_{}".format(case, metric), color=colors[case])
        plt.legend()
        # plt.savefig("./results/{}/{}/{}.png".format(experiment_name, case_name, metric))
        plt.show()

# %%
save_graphs(data,experiment_name, special_clients)
# Out:
# [2.343024, 3]
# [2.355744, 4]
# [2.404671, 7]
# [0.1743595006398957]
# [0.18462197860575183]
# [0.06843261777702654]
# [0.0]
# [0.0]
# [0.10948849]
# [0.0]
# [0.0]
# [0.068432614]
# [0.0]
# [0.0]
# [0.08422361]
