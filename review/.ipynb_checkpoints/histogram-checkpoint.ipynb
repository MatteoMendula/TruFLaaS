# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/diamonds.csv')
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
x1 = df.loc[df.cut=='Ideal', 'depth']
x2 = df.loc[df.cut=='Fair', 'depth']
x3 = df.loc[df.cut=='Good', 'depth']

print(x1)

kwargs = dict(alpha=0.5, bins=100)

plt.hist(x1, **kwargs, color='g', label='Ideal')
plt.hist(x2, **kwargs, color='b', label='Fair')
plt.hist(x3, **kwargs, color='r', label='Good')
plt.gca().set(title='Frequency Histogram of Diamond Depths', ylabel='Frequency')
plt.xlim(50,75)
plt.legend();
# Out:
# 0        61.5
# 11       62.8
# 13       62.2
# 16       62.0
# 39       61.8
#          ...
# 53925    61.6
# 53926    61.9
# 53929    61.4
# 53935    60.8
# 53939    62.2
# Name: depth, Length: 21551, dtype: float64

# %%
df = pd.read_pickle("./data/df.pkl")
df.head()
# Out:
#    MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  MI_dir_L3_weight  \
# 0          1.000000       60.000000            0.000000          1.000000
# 1          1.000000      590.000000            0.000000          1.000000
# 2          1.942585      590.000000            0.000000          1.965145
# 3          1.000000       60.000000            0.000000          1.000000
# 4          1.979600       66.061831           35.996177          1.987709
#
#    MI_dir_L3_mean  MI_dir_L3_variance  MI_dir_L1_weight  MI_dir_L1_mean  \
# 0         60.0000        0.000000e+00          1.000000       60.000000
# 1        590.0000        0.000000e+00          1.000000      590.000000
# 2        590.0000        1.160000e-10          1.988244      590.000000
# 3         60.0000        0.000000e+00          1.000000       60.000000
# 4         66.0371        3.599862e+01          1.995886       66.012367
#
#    MI_dir_L1_variance  MI_dir_L0.1_weight  ...  HpHp_L0.1_covariance  \
# ...

# %%
df["type"].value_counts()
# Out:
# mirai_udp         156248
# gafgyt_tcp        104510
# gafgyt_udp        104011
# mirai_scan         96781
# mirai_syn          65746
# benign             62154
# gafgyt_combo       61380
# mirai_ack          60554
# mirai_udpplain     56681
# gafgyt_junk        30898
# gafgyt_scan        29297
# Name: type, dtype: int64

# %%
plt.title("Class Distribution")
df.groupby("type").size().plot(kind='pie', autopct='%.2f', figsize=(20,10))
# Out:
# <Axes: title={'center': 'Class Distribution'}, ylabel='None'>

# %%
df.groupby("type").size()
# Out:
# type
# benign             62154
# gafgyt_combo       61380
# gafgyt_junk        30898
# gafgyt_scan        29297
# gafgyt_tcp        104510
# gafgyt_udp        104011
# mirai_ack          60554
# mirai_scan         96781
# mirai_syn          65746
# mirai_udp         156248
# mirai_udpplain     56681
# dtype: int64

# %%
kwargs = dict(alpha=0.5, bins=100)
for t in df.groupby("type").size().keys():
    print(t, df.groupby("type").size()[t])
    values = df.groupby("type").size()[t]
    plt.hist(values, **kwargs, color='g', label=t)
    plt.set(title='Frequency Histogram of Diamond Depths', ylabel='Frequency')
#     plt.xlim(50,75)
    plt.legend();
# Out:
# benign 62154
# gafgyt_combo 61380
# gafgyt_junk 30898
# gafgyt_scan 29297
# gafgyt_tcp 104510
# gafgyt_udp 104011
# mirai_ack 60554
# mirai_scan 96781
# mirai_syn 65746
# mirai_udp 156248
# mirai_udpplain 56681
