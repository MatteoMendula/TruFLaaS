# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
#for dirname, _, filenames in os.walk('/kaggle/input'):
    #for filename in filenames:
        #print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
benign_df = pd.read_csv('./data/5.benign.csv')

g_c_df = pd.read_csv('./data/5.gafgyt.combo.csv')
g_j_df = pd.read_csv('./data/5.gafgyt.junk.csv')
g_s_df = pd.read_csv('./data/5.gafgyt.scan.csv')
g_t_df = pd.read_csv('./data/5.gafgyt.tcp.csv')
g_u_df = pd.read_csv('./data/5.gafgyt.udp.csv')
m_a_df = pd.read_csv('./data/5.mirai.ack.csv')
m_sc_df = pd.read_csv('./data/5.mirai.scan.csv')
m_sy_df = pd.read_csv('./data/5.mirai.syn.csv')
m_u_df = pd.read_csv('./data/5.mirai.udp.csv')
m_u_p_df = pd.read_csv('./data/5.mirai.udpplain.csv')

# %%
benign_df['type'] = 'benign'
m_u_df['type'] = 'mirai_udp'
g_c_df['type'] = 'gafgyt_combo'
g_j_df['type'] = 'gafgyt_junk'
g_s_df['type'] = 'gafgyt_scan'
g_t_df['type'] = 'gafgyt_tcp'
g_u_df['type'] = 'gafgyt_udp'
m_a_df['type'] = 'mirai_ack'
m_sc_df['type'] = 'mirai_scan'
m_sy_df['type'] = 'mirai_syn'
m_u_p_df['type'] = 'mirai_udpplain'

# %%
df = pd.concat([benign_df, m_u_df, g_c_df,
                g_j_df, g_s_df, g_t_df,
                g_u_df, m_a_df, m_sc_df,
                m_sy_df, m_u_p_df],
                axis=0, sort=False, ignore_index=True)

# %%
df["type"].value_counts()
# Out:
# mirai_udp         156248
# gafgyt_tcp        104510
# gafgyt_udp        104011
# mirai_scan         96781
# mirai_syn          65746
# benign             62154
# gafgyt_combo       61380
# mirai_ack          60554
# mirai_udpplain     56681
# gafgyt_junk        30898
# gafgyt_scan        29297
# Name: type, dtype: int64

# %%
from matplotlib import pyplot as plt

plt.title("Class Distribution")
df.groupby("type").size().plot(kind='pie', autopct='%.2f', figsize=(20,10))
# Out:
# <AxesSubplot:title={'center':'Class Distribution'}, ylabel='None'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 828260 entries, 0 to 828259
# Columns: 116 entries, MI_dir_L5_weight to type
# dtypes: float64(115), object(1)
# memory usage: 733.0+ MB

# %%
df = df.sample(frac=1).reset_index(drop=True)

# %%
df.head()
# Out:
#    MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  MI_dir_L3_weight  \
# 0         69.831095       70.785439           34.984865        148.936386
# 1          1.621695       68.016303           39.950825          1.834089
# 2         63.755897      256.709175        58270.399468        108.124796
# 3         85.703686       60.000002            0.000024        115.815674
# 4        108.822029       60.069459            1.517377        131.595568
#
#    MI_dir_L3_mean  MI_dir_L3_variance  MI_dir_L1_weight  MI_dir_L1_mean  \
# 0       69.475149           43.228392        472.458476       68.581808
# 1       67.087986           41.904273          2.563719       65.071571
# 2      294.287770        60707.038884        349.307959      313.444310
# 3       60.000171            0.002172        249.163757       60.014413
# 4       60.128872            2.703038        268.033197       60.176545
#
#    MI_dir_L1_variance  MI_dir_L0.1_weight  ...  HpHp_L0.1_covariance  \
# 0           46.776555         2772.407472  ...                   0.0
# 1           40.219357            5.740490  ...                   0.0
# 2        60910.963364         3007.504472  ...                   0.0
# 3            0.229748         2056.884740  ...                   0.0
# 4            3.440744         2067.360313  ...                   0.0
#
#    HpHp_L0.1_pcc  HpHp_L0.01_weight  HpHp_L0.01_mean  HpHp_L0.01_std  \
# 0            0.0                1.0             74.0             0.0
# 1            0.0                1.0             73.0             0.0
# 2            0.0                1.0             60.0             0.0
# 3            0.0                1.0             60.0             0.0
# 4            0.0                1.0             60.0             0.0
#
#    HpHp_L0.01_magnitude  HpHp_L0.01_radius  HpHp_L0.01_covariance  \
# 0                  74.0                0.0                    0.0
# 1                  73.0                0.0                    0.0
# 2                  60.0                0.0                    0.0
# 3                  60.0                0.0                    0.0
# 4                  60.0                0.0                    0.0
#
#    HpHp_L0.01_pcc            type
# 0             0.0       mirai_syn
# 1             0.0          benign
# 2             0.0  mirai_udpplain
# 3             0.0      mirai_scan
# 4             0.0      mirai_scan
#
# [5 rows x 116 columns]

# %%
from sklearn.model_selection import train_test_split

train_df, test_df = train_test_split(df, test_size=0.2, random_state=42, stratify=df["type"])

# %%
features = list(train_df.columns)
features.remove("type")
#features

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
train_df["type"] = label_encoder.fit_transform(train_df["type"])
test_df["type"] = label_encoder.transform(test_df["type"])

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
train_df[features] = scaler.fit_transform(train_df[features])
test_df[features] = scaler.transform(test_df[features])

# %%
X_train = train_df[features].values
y_train = train_df["type"].values

X_test = test_df[features].values
y_test = test_df["type"].values

# %%
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.feature_selection import SelectFromModel


clf = ExtraTreesClassifier(n_estimators=50, n_jobs=-1)
clf = clf.fit(X_train, y_train)
clf.feature_importances_
# Out:
# array([5.59509446e-03, 7.86469751e-03, 5.24792842e-03, 1.00492368e-02,
#        4.19585494e-03, 7.40500815e-03, 1.17441132e-02, 8.96131724e-03,
#        6.00753011e-03, 2.19192252e-02, 4.99812326e-02, 2.01333112e-02,
#        3.22468547e-02, 4.19410744e-02, 4.12872152e-02, 1.47528769e-02,
#        6.36868094e-03, 8.02666423e-03, 5.46052253e-03, 2.41050201e-03,
#        7.85080138e-03, 3.01770555e-02, 1.80161757e-02, 9.42571376e-03,
#        3.02613586e-02, 2.45673410e-02, 2.75248354e-02, 4.05976055e-02,
#        4.64459616e-02, 3.30175727e-02, 3.32528736e-03, 6.53956966e-03,
#        5.44077062e-04, 4.40548816e-03, 1.55257620e-03, 2.54929422e-05,
#        1.04117165e-05, 1.22457035e-02, 2.36558397e-03, 7.27097685e-04,
#        3.34743921e-03, 6.51667699e-05, 1.36041102e-06, 1.52844676e-04,
#        1.61617821e-02, 6.57550324e-03, 7.08092476e-04, 5.15598371e-03,
#        7.94913741e-04, 1.57674603e-06, 3.07753178e-04, 1.77208094e-02,
#        5.09328215e-03, 2.20406834e-03, 9.33992967e-03, 4.18019725e-04,
#        3.16520076e-05, 6.64200476e-04, 7.96665388e-03, 1.17238229e-02,
#        6.74923783e-03, 9.45848269e-03, 5.02238507e-03, 9.12426033e-06,
#        4.53463108e-05, 6.21295952e-03, 4.08060646e-02, 9.12679311e-05,
#        5.13816622e-03, 2.96102166e-02, 1.20154732e-04, 8.66329061e-03,
#        2.07618012e-02, 2.49047197e-04, 9.63694375e-03, 3.66917071e-02,
#        4.92731024e-03, 6.60918192e-03, 3.81568342e-02, 6.53344178e-03,
#        3.39797244e-03, 1.11902369e-03, 4.20082859e-04, 3.60485532e-03,
#        2.87174833e-04, 1.90967035e-04, 2.01033529e-04, 4.48931414e-03,
#        1.22916980e-03, 1.25799798e-04, 4.54520245e-03, 1.72578933e-04,
#        1.01934490e-05, 3.76192604e-07, 4.55730871e-03, 5.36724921e-03,
#        8.87778328e-06, 4.99645602e-03, 4.46273189e-06, 1.17022243e-06,
#        3.02436390e-05, 8.12990348e-03, 1.88841326e-03, 1.28038236e-03,
#        2.08302790e-03, 2.35588425e-04, 1.53599294e-06, 2.73059293e-06,
#        6.87671858e-03, 2.08690893e-03, 1.66803413e-03, 5.80403429e-03,
#        2.83631142e-05, 7.97238819e-07, 1.58037743e-06])

# %%
ext=pd.DataFrame(clf.feature_importances_,columns=["extratrees_importance"])
ext = ext.sort_values(['extratrees_importance'], ascending=False)
feature_index = [features[i] for i in list(ext.index)]
ext["Feature_Name"] = feature_index
ext
# Out:
#      extratrees_importance           Feature_Name
# 10            4.998123e-02       MI_dir_L0.1_mean
# 28            4.644596e-02           H_L0.01_mean
# 13            4.194107e-02      MI_dir_L0.01_mean
# 14            4.128722e-02  MI_dir_L0.01_variance
# 66            4.080606e-02         HH_jit_L5_mean
# ..                     ...                    ...
# 106           1.535993e-06   HpHp_L0.1_covariance
# 42            1.360411e-06       HH_L3_covariance
# 99            1.170222e-06     HpHp_L1_covariance
# 113           7.972388e-07  HpHp_L0.01_covariance
# 93            3.761926e-07            HpHp_L3_pcc
#
# [115 rows x 2 columns]

# %%
model = SelectFromModel(clf, prefit=True)
X_train = model.transform(X_train)
X_test = model.transform(X_test)
X_test.shape
# Out:
# (165652, 31)

# %%
X_train = X_train.reshape((-1, X_train.shape[-1], 1))
X_test = X_test.reshape((-1, X_test.shape[-1], 1))

# %%
from sklearn.utils import class_weight

class_weights = class_weight.compute_class_weight('balanced',
                                                 classes=np.unique(y_train),
                                                 y=y_train)

class_weights = {k: v for k,v in enumerate(class_weights)}
class_weights
# Out:
# {0: 1.2114532692937052,
#  1: 1.2267247252584497,
#  2: 2.43697268828752,
#  3: 2.5700610508187944,
#  4: 0.7204704204034411,
#  5: 0.7239251872885254,
#  6: 1.2434632642299384,
#  7: 0.7780056946605219,
#  8: 1.1452571612276539,
#  9: 0.48190443774373115,
#  10: 1.3284174861416012}

# %%
input_shape = X_train.shape[1:]
nb_classes = len(label_encoder.classes_)

# %%
from tensorflow.keras.utils import to_categorical

def convert_to_categorical(y, nb_classes):
    return to_categorical(y, num_classes=nb_classes)

# %%
def iid_data_indices(labels: np.ndarray, nb_clients: int):
    data_len = len(labels)
    indices = np.arange(data_len)
    np.random.shuffle(indices)
    chunks = np.array_split(indices, nb_clients)
    return chunks

# %%
def non_iid_data_indices(labels: np.ndarray, nb_clients: int, nb_shards: int = 200):
    data_len = len(labels)
    indices = np.arange(data_len)
    indices = indices[labels.argsort()]
    shards = np.array_split(indices, nb_shards)
    random.shuffle(shards)
    shards_for_users = np.array_split(shards, nb_clients)
    indices_for_users = [np.hstack(x) for x in shards_for_users]
    return indices_for_users

# %%
def sample(y:np.ndarray, sampling_technique: str, nb_clients: int):
    if sampling_technique.lower() == "iid":
        sampler_fn = iid_data_indices
    else:
        sampler_fn = non_iid_data_indices
    client_data_indices = sampler_fn(y, nb_clients)
    return client_data_indices

# %%
def assign_data_to_clients(clients: dict, X:np.ndarray, y:np.ndarray, nb_classes:int, sampling_technique: str):
    sampled_data_indices = sample(y, sampling_technique, len(clients.keys()))
    for client_name, data_indices in zip(clients.keys(), sampled_data_indices):
        X = X_train[data_indices]
        y = y_train[data_indices]
        y = convert_to_categorical(y, nb_classes)
        clients[client_name] = list(zip(X, y))
    return clients

# %%
def create_clients(X, y, nb_classes, sampling_technique, num_clients=10, initial='clients'):
    #create a list of client names
    client_names = ['{}_{}'.format(initial, i+1) for i in range(num_clients)]
    clients = {client_names[i] : [] for i in range(len(client_names))}
    return assign_data_to_clients(clients, X, y, nb_classes, sampling_technique)

# %%
import tensorflow as tf

def batch_data(data_shard, batch_size=64):
    #seperate shard into data and labels lists
    data, label = zip(*data_shard)
    del data_shard

    len_label = len(label)
    dataset = tf.data.Dataset.from_tensor_slices((list(data), list(label)))
    del data, label
    return dataset.shuffle(len_label).batch(batch_size)

# %%
from keras.layers import Conv1D, MaxPool1D, BatchNormalization, Activation, Input, Add, \
                         GlobalAveragePooling1D, Dense, concatenate
from keras.models import Model
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.metrics import Recall, Precision
import keras
import time
import os

# %%
import keras.backend as K
import tensorflow as tf

def f1_score(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %%
from keras import layers
from keras.layers import Conv1D, MaxPooling1D, Concatenate, Activation, BatchNormalization

class INCEPTION_Block(keras.layers.Layer):
    def __init__(self, **kwargs):
        super(INCEPTION_Block, self).__init__(**kwargs)
        self.kernel_size = 50
#         f1, f2_in, f2_out, f3_in, f3_out, f4_out = (128, 128, 192, 32, 96, 64)
        f1, f2_in, f2_out, f3_in, f3_out, f4_out = (16, 16, 24, 4, 12, 8)
        kernel_size_s = [10, 30, 50]
        
        # 1x1 conv
        self.conv_1_1 = Conv1D(f1, kernel_size_s[0], padding='same', activation='relu')
        
        # 3x3 conv
        self.conv_1_2 = Conv1D(f2_in, kernel_size_s[0], padding='same', activation='relu')
        self.conv_3_2 = Conv1D(f2_out, kernel_size_s[1], padding='same', activation='relu')
        
        # 5x5 conv
        self.conv_1_3 = Conv1D(f3_in, kernel_size_s[0], padding='same', activation='relu')
        self.conv_5_3 = Conv1D(f3_out, kernel_size_s[2], padding='same', activation='relu')
        
        # 3x3 max pooling
        self.pool = MaxPooling1D(kernel_size_s[1], strides=1, padding='same')
        self.conv_final = Conv1D(f4_out, kernel_size_s[0], padding='same', activation='relu')
        
        # concatenate filters, assumes filters/channels last
        self.concatenate = Concatenate(axis=-1)
        
        self.batch_normalization = BatchNormalization()
        self.relu_activation = Activation(activation='relu')
        
    def call(self, layer_in):
        # 1x1 conv
        conv1 = self.conv_1_1(layer_in)
        
        # 3x3 conv
        conv3 = self.conv_1_2(layer_in)
        conv3 = self.conv_3_2(conv3)
        
        # 5x5 conv
        conv5 = self.conv_1_3(layer_in)
        conv5 = self.conv_5_3(conv5)
        
        # 3x3 max pooling
        pool = self.pool(layer_in)
        pool = self.conv_final(pool)
        
        # concatenate filters, assumes filters/channels last
        layer_out = self.concatenate([conv1, conv3, conv5, pool])
        
        layer_out = self.batch_normalization(layer_out)
        layer_out = self.relu_activation(layer_out)
        
        return layer_out

def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Attention and Normalization
    x = layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
    )(inputs, inputs)
    x = layers.Dropout(dropout)(x)
    x = layers.LayerNormalization(epsilon=1e-6)(x)
    res = x + inputs

    # Feed Forward Part
    x = keras.models.Sequential(
        [INCEPTION_Block(),
         INCEPTION_Block(),
         INCEPTION_Block()])(res)
    x = layers.Dropout(dropout)(x)
    x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    x = layers.LayerNormalization(epsilon=1e-6)(x)
    return x + res

class TransformerEncoder(layers.Layer):
    def __init__(self, head_size, num_heads, neurons):
        super(TransformerEncoder, self).__init__()
        self.att = layers.MultiHeadAttention(num_heads=num_heads, key_dim=head_size)
        self.ffn = keras.models.Sequential(
            #[layers.Dense(neurons, activation="relu"), layers.Dense(head_size),]
            [
                INCEPTION_Block(),
                INCEPTION_Block(),
                INCEPTION_Block(),
            ]
        )
        self.layernorm1 = layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = layers.LayerNormalization(epsilon=1e-6)
        self.dropout1 = layers.Dropout(0.1)
        self.dropout2 = layers.Dropout(0.1)

    def call(self, inputs, training):
        attn_output = self.att(inputs, inputs)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(inputs + attn_output)
        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output, training=training)
        return self.layernorm2(out1 + ffn_output)

def get_model(input_shape, nb_classes) -> tf.keras.Model:
    head_size=64 # Embedding size for attention
    num_heads=3 # Number of attention heads
    ff_dim=128 # Hidden layer size in feed forward network inside transformer
    num_transformer_blocks=1
    mlp_units=[32]
    mlp_dropout=0.1
    dropout=0.1

    inputs = keras.Input(shape=input_shape)
    x = inputs
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    x = layers.GlobalAveragePooling1D(data_format="channels_first")(x)
    for dim in mlp_units:
        x = layers.Dense(dim, activation="relu")(x)
        x = layers.Dropout(mlp_dropout)(x)
    outputs = layers.Dense(nb_classes, activation="softmax")(x)

    return keras.Model(inputs, outputs)

# %%
from keras.metrics import Recall, Precision
from keras.utils.vis_utils import plot_model

learning_rate = 1e-2
comms_round = 10
loss='categorical_crossentropy'
metrics = ["accuracy", Recall(), Precision(), f1_score]
optimizer = tf.keras.optimizers.legacy.RMSprop(learning_rate=learning_rate)

#initialize global model
global_model = get_model(input_shape, nb_classes)

global_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 31, 1)]      0           []
#
#  multi_head_attention (MultiHea  (None, 31, 1)       1345        ['input_1[0][0]',
#  dAttention)                                                      'input_1[0][0]']
#
#  dropout (Dropout)              (None, 31, 1)        0           ['multi_head_attention[0][0]']
#
#  layer_normalization (LayerNorm  (None, 31, 1)       2           ['dropout[0][0]']
#  alization)
#
#  tf.__operators__.add (TFOpLamb  (None, 31, 1)       0           ['layer_normalization[0][0]',
#  da)                                                              'input_1[0][0]']
#
#  sequential (Sequential)        (None, 31, 60)       95960       ['tf.__operators__.add[0][0]']
#
#  dropout_1 (Dropout)            (None, 31, 60)       0           ['sequential[0][0]']
#
#  conv1d_18 (Conv1D)             (None, 31, 1)        61          ['dropout_1[0][0]']
#
#  layer_normalization_1 (LayerNo  (None, 31, 1)       2           ['conv1d_18[0][0]']
#  rmalization)
#
#  tf.__operators__.add_1 (TFOpLa  (None, 31, 1)       0           ['layer_normalization_1[0][0]',
#  mbda)                                                            'tf.__operators__.add[0][0]']
#
#  global_average_pooling1d (Glob  (None, 31)          0           ['tf.__operators__.add_1[0][0]']
#  alAveragePooling1D)
#
#  dense (Dense)                  (None, 32)           1024        ['global_average_pooling1d[0][0]'
#                                                                  ]
#
#  dropout_2 (Dropout)            (None, 32)           0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 11)           363         ['dropout_2[0][0]']
#
# ==================================================================================================
# Total params: 98,757
# Trainable params: 98,397
# Non-trainable params: 360
# __________________________________________________________________________________________________

# %%
plot_model(global_model, to_file='global_model.png', show_shapes=True, show_layer_names=True)

# %%
BATCH_SIZE = 64
sampling_technique = "iid"

# create clients
clients_batched = create_clients(X_train, y_train, nb_classes, sampling_technique, num_clients=10, initial='client')

del X_train, y_train

# process and batch the training data for each client
client_set = {k: {} for k in clients_batched.keys()}

for (client_name, data) in clients_batched.items():
    client_set[client_name]["dataset"] = batch_data(data, BATCH_SIZE)
    local_model = get_model(input_shape, nb_classes)
    local_model.compile(loss=loss, 
                      optimizer=optimizer, 
                      metrics=metrics)
    client_set[client_name]["model"] = local_model

# %%
#process and batch the test set 

y_test = convert_to_categorical(y_test, nb_classes)

test_batched = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(len(y_test))

del X_test, y_test

# %%
def weight_scalling_factor(clients, client_name):
    client_names = list(clients.keys())
    #get the bs
    bs = list(clients[client_name]["dataset"])[0][0].shape[0]
    #first calculate the total training data points across clinets
    global_count = sum([tf.data.experimental.cardinality(clients[client_name]["dataset"]).numpy() for client_name in client_names])*bs
    # get the total number of data points held by a client
    local_count = tf.data.experimental.cardinality(clients[client_name]["dataset"]).numpy()*bs
    return local_count/global_count

# %%
def scale_model_weights(weight, scalar):
    '''function for scaling a models weights'''
    weight_final = []
    steps = len(weight)
    for i in range(steps):
        weight_final.append(scalar * weight[i])
    return weight_final

# %%
def sum_scaled_weights(scaled_weight_list):
    '''Return the sum of the listed scaled weights. The is equivalent to scaled avg of the weights'''
    avg_grad = list()
    #get the average grad accross all client gradients
    for grad_list_tuple in zip(*scaled_weight_list):
        layer_mean = tf.math.reduce_sum(grad_list_tuple, axis=0)
        avg_grad.append(layer_mean)
        
    return avg_grad

# %%
from sklearn.metrics import accuracy_score

def test_model(X_test, y_test,  model, comm_round):
    cce = tf.keras.losses.CategoricalCrossentropy(from_logits=True)
    #logits = model.predict(X_test, batch_size=100)
    logits = model.predict(X_test)
    loss = cce(y_test, logits)
    y_hat = np.argmax(logits, axis=1)
    y_true = np.argmax(y_test, axis=1)

    accuracy = accuracy_score(np.argmax(y_test, axis=1), np.argmax(logits, axis=1))
    
    r = Recall()
    r.update_state(y_test, logits)
    recall = r.result().numpy()
    
    p = Precision()
    p.update_state(y_test, logits)
    precision = p.result().numpy()
    
    f = f1_score(y_test, logits)
    f1 = f.numpy()
    
    print('comm_round: {} | global_loss: {} | global_accuracy: {:.4} | global_recall: {:.4} | global_precision: {:.4} | global_f1_score: {:.4} \n'.format(comm_round, loss, accuracy, recall, precision, f1))
    return loss, accuracy, precision, recall, f1

# %%
def train_client(client, global_weights, class_weights):
    client_set[client]["model"] = client_set[client]["model"]

    #set local model weight to the weight of the global model
    client_set[client]["model"].set_weights(global_weights)

    #fit local model with client's data
    print(f"Round: {comm_round} | Client: {client} training")
    client_set[client]["model"].fit(client_set[client]["dataset"], epochs=1, verbose=1, class_weight=class_weights)

    #scale the model weights and add to list
    scaling_factor = weight_scalling_factor(client_set, client)
    scaled_weights = scale_model_weights(local_model.get_weights(), scaling_factor)
    return scaled_weights

# %%
import random 

#commence global training loop
global_loss=[]
global_accuracy=[]
global_precision=[]
global_recall=[]
global_f1=[]
best_global_accuracy = 0

for comm_round in range(comms_round):            
    # get the global model's weights - will serve as the initial weights for all local models
    global_weights = global_model.get_weights()
    
    #initial list to collect local model weights after scalling
    scaled_local_weight_list = list()

    #randomize client data - using keys
    client_names= list(client_set.keys())
    random.shuffle(client_names)
    
    #loop through each client and create new local model
    for client in client_names:            
        scaled_weights = train_client(client, global_weights, class_weights)
            
        scaled_local_weight_list.append(scaled_weights)
        
    #to get the average over all the local model, we simply take the sum of the scaled weights
    average_weights = sum_scaled_weights(scaled_local_weight_list)
    
    #update global model 
    global_model.set_weights(average_weights)

    #test global model and print out metrics after each communications round
    g_accuracy = 0
    for(x_batch, y_batch) in test_batched:
        g_loss, g_accuracy, g_precision, g_recall, g_f1 = test_model(x_batch, y_batch, global_model, comm_round)
        global_loss.append(g_loss)
        global_accuracy.append(g_accuracy)
        global_precision.append(g_precision)
        global_recall.append(g_recall)
        global_f1.append(g_f1)
        
    if g_accuracy > best_global_accuracy:
        best_global_accuracy = g_accuracy
        global_model.save_weights('global_model_best_weights.h5')
        print("New Weights Saved")
# Out:
# Round: 0 | Client: client_4 training
# 1036/1036 [==============================] - 27s 18ms/step - loss: 0.4729 - accuracy: 0.7499 - recall: 0.7049 - precision: 0.7778 - f1_score: 0.7308
# Round: 0 | Client: client_9 training
# 1036/1036 [==============================] - 23s 17ms/step - loss: 0.4672 - accuracy: 0.7523 - recall: 0.7056 - precision: 0.7798 - f1_score: 0.7318
# Round: 0 | Client: client_1 training
# 1036/1036 [==============================] - 23s 17ms/step - loss: 0.4736 - accuracy: 0.7461 - recall: 0.7044 - precision: 0.7785 - f1_score: 0.7266
# Round: 0 | Client: client_10 training
# 1036/1036 [==============================] - 23s 18ms/step - loss: 0.4695 - accuracy: 0.7496 - recall: 0.7049 - precision: 0.7787 - f1_score: 0.7308
# Round: 0 | Client: client_8 training
# 1036/1036 [==============================] - 23s 18ms/step - loss: 0.4684 - accuracy: 0.7491 - recall: 0.7054 - precision: 0.7785 - f1_score: 0.7314
# Round: 0 | Client: client_6 training
# 1036/1036 [==============================] - 23s 17ms/step - loss: 0.4777 - accuracy: 0.7454 - recall: 0.7046 - precision: 0.7783 - f1_score: 0.7263
# Round: 0 | Client: client_5 training
# 1036/1036 [==============================] - 22s 17ms/step - loss: 0.4667 - accuracy: 0.7538 - recall: 0.7055 - precision: 0.7788 - f1_score: 0.7355
# Round: 0 | Client: client_2 training
# 1036/1036 [==============================] - 23s 18ms/step - loss: 0.4742 - accuracy: 0.7470 - recall: 0.7052 - precision: 0.7786 - f1_score: 0.7280
# Round: 0 | Client: client_3 training
# 1036/1036 [==============================] - 23s 18ms/step - loss: 0.4694 - accuracy: 0.7503 - recall: 0.7056 - precision: 0.7784 - f1_score: 0.7318
# Round: 0 | Client: client_7 training
# 1036/1036 [==============================] - 24s 18ms/step - loss: 0.4844 - accuracy: 0.7421 - recall: 0.7046 - precision: 0.7777 - f1_score: 0.7206
# 5177/5177 [==============================] - 20s 4ms/step
# comm_round: 0 | global_loss: 1.902101993560791 | global_accuracy: 0.7113 | global_recall: 0.5792 | global_precision: 0.7864 | global_f1_score: 0.6671
#
# New Weights Saved
# Round: 1 | Client: client_4 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.3297 - accuracy: 0.8058 - recall: 0.7961 - precision: 0.8130 - f1_score: 0.8042
# Round: 1 | Client: client_2 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.3256 - accuracy: 0.8048 - recall: 0.7939 - precision: 0.8125 - f1_score: 0.8029
# Round: 1 | Client: client_10 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.3275 - accuracy: 0.8034 - recall: 0.7924 - precision: 0.8107 - f1_score: 0.8011
# Round: 1 | Client: client_7 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.3268 - accuracy: 0.8036 - recall: 0.7937 - precision: 0.8106 - f1_score: 0.8019
# Round: 1 | Client: client_3 training
# 1036/1036 [==============================] - 18s 18ms/step - loss: 0.3279 - accuracy: 0.8025 - recall: 0.7926 - precision: 0.8097 - f1_score: 0.8010
# Round: 1 | Client: client_6 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.3296 - accuracy: 0.8040 - recall: 0.7941 - precision: 0.8110 - f1_score: 0.8022
# Round: 1 | Client: client_8 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.3285 - accuracy: 0.8039 - recall: 0.7943 - precision: 0.8109 - f1_score: 0.8023
# Round: 1 | Client: client_1 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.3254 - accuracy: 0.8037 - recall: 0.7933 - precision: 0.8109 - f1_score: 0.8018
# Round: 1 | Client: client_5 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.3293 - accuracy: 0.8012 - recall: 0.7903 - precision: 0.8086 - f1_score: 0.7991
# Round: 1 | Client: client_9 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.3243 - accuracy: 0.8039 - recall: 0.7942 - precision: 0.8106 - f1_score: 0.8021
# 5177/5177 [==============================] - 20s 4ms/step
# comm_round: 1 | global_loss: 1.7263133525848389 | global_accuracy: 0.827 | global_recall: 0.8268 | global_precision: 0.8273 | global_f1_score: 0.827
#
# New Weights Saved
# Round: 2 | Client: client_3 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.2884 - accuracy: 0.8198 - recall: 0.8150 - precision: 0.8234 - f1_score: 0.8191
# Round: 2 | Client: client_5 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.2911 - accuracy: 0.8179 - recall: 0.8134 - precision: 0.8218 - f1_score: 0.8175
# Round: 2 | Client: client_4 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.2902 - accuracy: 0.8192 - recall: 0.8142 - precision: 0.8230 - f1_score: 0.8185
# Round: 2 | Client: client_8 training
# 1036/1036 [==============================] - 18s 18ms/step - loss: 0.2916 - accuracy: 0.8200 - recall: 0.8150 - precision: 0.8234 - f1_score: 0.8192
# Round: 2 | Client: client_2 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.2848 - accuracy: 0.8234 - recall: 0.8188 - precision: 0.8272 - f1_score: 0.8229
# Round: 2 | Client: client_1 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.2869 - accuracy: 0.8206 - recall: 0.8167 - precision: 0.8237 - f1_score: 0.8200
# Round: 2 | Client: client_9 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.2853 - accuracy: 0.8186 - recall: 0.8147 - precision: 0.8222 - f1_score: 0.8184
# Round: 2 | Client: client_10 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.2896 - accuracy: 0.8196 - recall: 0.8144 - precision: 0.8235 - f1_score: 0.8188
# Round: 2 | Client: client_6 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.2919 - accuracy: 0.8205 - recall: 0.8150 - precision: 0.8249 - f1_score: 0.8198
# Round: 2 | Client: client_7 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.2914 - accuracy: 0.8204 - recall: 0.8160 - precision: 0.8240 - f1_score: 0.8199
# 5177/5177 [==============================] - 20s 4ms/step
# comm_round: 2 | global_loss: 1.716047763824463 | global_accuracy: 0.8333 | global_recall: 0.833 | global_precision: 0.8335 | global_f1_score: 0.8333
#
# New Weights Saved
# Round: 3 | Client: client_10 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.2824 - accuracy: 0.8234 - recall: 0.8191 - precision: 0.8269 - f1_score: 0.8229
# Round: 3 | Client: client_5 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.2819 - accuracy: 0.8232 - recall: 0.8190 - precision: 0.8270 - f1_score: 0.8230
# Round: 3 | Client: client_9 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.2753 - accuracy: 0.8236 - recall: 0.8196 - precision: 0.8265 - f1_score: 0.8230
# Round: 3 | Client: client_6 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.2826 - accuracy: 0.8240 - recall: 0.8199 - precision: 0.8275 - f1_score: 0.8237
# Round: 3 | Client: client_1 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.2767 - accuracy: 0.8237 - recall: 0.8202 - precision: 0.8266 - f1_score: 0.8233
# Round: 3 | Client: client_4 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.2831 - accuracy: 0.8237 - recall: 0.8193 - precision: 0.8266 - f1_score: 0.8229
# Round: 3 | Client: client_8 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.2823 - accuracy: 0.8235 - recall: 0.8185 - precision: 0.8269 - f1_score: 0.8225
# Round: 3 | Client: client_3 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.2804 - accuracy: 0.8235 - recall: 0.8194 - precision: 0.8272 - f1_score: 0.8232
# Round: 3 | Client: client_2 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.2794 - accuracy: 0.8256 - recall: 0.8222 - precision: 0.8287 - f1_score: 0.8254
# Round: 3 | Client: client_7 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.2827 - accuracy: 0.8247 - recall: 0.8206 - precision: 0.8272 - f1_score: 0.8238
# 5177/5177 [==============================] - 20s 4ms/step
# comm_round: 3 | global_loss: 1.7108486890792847 | global_accuracy: 0.8369 | global_recall: 0.8364 | global_precision: 0.8379 | global_f1_score: 0.8372
#
# New Weights Saved
# Round: 4 | Client: client_4 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.2759 - accuracy: 0.8275 - recall: 0.8242 - precision: 0.8307 - f1_score: 0.8274
# Round: 4 | Client: client_6 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.2699 - accuracy: 0.8282 - recall: 0.8251 - precision: 0.8306 - f1_score: 0.8278
# Round: 4 | Client: client_8 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.2718 - accuracy: 0.8263 - recall: 0.8229 - precision: 0.8293 - f1_score: 0.8260
# Round: 4 | Client: client_9 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.2645 - accuracy: 0.8274 - recall: 0.8240 - precision: 0.8303 - f1_score: 0.8270
# Round: 4 | Client: client_2 training
# 1036/1036 [==============================] - 19s 19ms/step - loss: 0.2686 - accuracy: 0.8282 - recall: 0.8250 - precision: 0.8318 - f1_score: 0.8282
# Round: 4 | Client: client_3 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.2677 - accuracy: 0.8299 - recall: 0.8258 - precision: 0.8331 - f1_score: 0.8293
# Round: 4 | Client: client_5 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.2745 - accuracy: 0.8270 - recall: 0.8233 - precision: 0.8301 - f1_score: 0.8266
# Round: 4 | Client: client_10 training
# 1036/1036 [==============================] - 19s 19ms/step - loss: 0.2686 - accuracy: 0.8304 - recall: 0.8265 - precision: 0.8337 - f1_score: 0.8300
# Round: 4 | Client: client_1 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.2653 - accuracy: 0.8287 - recall: 0.8249 - precision: 0.8311 - f1_score: 0.8279
# Round: 4 | Client: client_7 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.2719 - accuracy: 0.8273 - recall: 0.8238 - precision: 0.8306 - f1_score: 0.8271
# 5177/5177 [==============================] - 21s 4ms/step
# comm_round: 4 | global_loss: 1.7050185203552246 | global_accuracy: 0.8382 | global_recall: 0.8379 | global_precision: 0.8385 | global_f1_score: 0.8382
#
# New Weights Saved
# Round: 5 | Client: client_4 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.2702 - accuracy: 0.8304 - recall: 0.8271 - precision: 0.8337 - f1_score: 0.8303
# Round: 5 | Client: client_9 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.2600 - accuracy: 0.8290 - recall: 0.8265 - precision: 0.8315 - f1_score: 0.8289
# Round: 5 | Client: client_7 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.2685 - accuracy: 0.8302 - recall: 0.8266 - precision: 0.8331 - f1_score: 0.8298
# Round: 5 | Client: client_6 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.2691 - accuracy: 0.8308 - recall: 0.8273 - precision: 0.8335 - f1_score: 0.8303
# Round: 5 | Client: client_10 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.2665 - accuracy: 0.8289 - recall: 0.8262 - precision: 0.8314 - f1_score: 0.8287
# Round: 5 | Client: client_5 training
# 1036/1036 [==============================] - 19s 19ms/step - loss: 0.2693 - accuracy: 0.8248 - recall: 0.8216 - precision: 0.8278 - f1_score: 0.8247
# Round: 5 | Client: client_2 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.2626 - accuracy: 0.8299 - recall: 0.8262 - precision: 0.8331 - f1_score: 0.8296
# Round: 5 | Client: client_3 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.2655 - accuracy: 0.8276 - recall: 0.8237 - precision: 0.8306 - f1_score: 0.8271
# Round: 5 | Client: client_8 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.2689 - accuracy: 0.8276 - recall: 0.8240 - precision: 0.8307 - f1_score: 0.8272
# Round: 5 | Client: client_1 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.2600 - accuracy: 0.8304 - recall: 0.8276 - precision: 0.8327 - f1_score: 0.8301
# 5177/5177 [==============================] - 20s 4ms/step
# comm_round: 5 | global_loss: 1.698014736175537 | global_accuracy: 0.8424 | global_recall: 0.8422 | global_precision: 0.8424 | global_f1_score: 0.8423
#
# New Weights Saved
# Round: 6 | Client: client_6 training
# 1036/1036 [==============================] - 19s 19ms/step - loss: 0.2652 - accuracy: 0.8340 - recall: 0.8312 - precision: 0.8363 - f1_score: 0.8337
# Round: 6 | Client: client_4 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.2657 - accuracy: 0.8301 - recall: 0.8272 - precision: 0.8331 - f1_score: 0.8300
# Round: 6 | Client: client_3 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.2622 - accuracy: 0.8305 - recall: 0.8275 - precision: 0.8330 - f1_score: 0.8302
# Round: 6 | Client: client_1 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.2550 - accuracy: 0.8326 - recall: 0.8296 - precision: 0.8347 - f1_score: 0.8321
# Round: 6 | Client: client_2 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.2595 - accuracy: 0.8325 - recall: 0.8295 - precision: 0.8348 - f1_score: 0.8320
# Round: 6 | Client: client_9 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.2553 - accuracy: 0.8297 - recall: 0.8270 - precision: 0.8321 - f1_score: 0.8295
# Round: 6 | Client: client_7 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.2637 - accuracy: 0.8322 - recall: 0.8297 - precision: 0.8344 - f1_score: 0.8321
# Round: 6 | Client: client_5 training
# 1036/1036 [==============================] - 18s 18ms/step - loss: 0.2651 - accuracy: 0.8281 - recall: 0.8248 - precision: 0.8307 - f1_score: 0.8276
# Round: 6 | Client: client_10 training
# 1036/1036 [==============================] - 20s 19ms/step - loss: 0.2616 - accuracy: 0.8322 - recall: 0.8293 - precision: 0.8349 - f1_score: 0.8319
# Round: 6 | Client: client_8 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.2653 - accuracy: 0.8323 - recall: 0.8292 - precision: 0.8349 - f1_score: 0.8319
# 5177/5177 [==============================] - 20s 4ms/step
# comm_round: 6 | global_loss: 1.69709050655365 | global_accuracy: 0.8438 | global_recall: 0.8436 | global_precision: 0.8439 | global_f1_score: 0.8437
#
# New Weights Saved
# Round: 7 | Client: client_5 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.2646 - accuracy: 0.8293 - recall: 0.8264 - precision: 0.8321 - f1_score: 0.8291
# Round: 7 | Client: client_7 training
# 1036/1036 [==============================] - 20s 19ms/step - loss: 0.2643 - accuracy: 0.8335 - recall: 0.8309 - precision: 0.8360 - f1_score: 0.8334
# Round: 7 | Client: client_1 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.2564 - accuracy: 0.8326 - recall: 0.8302 - precision: 0.8346 - f1_score: 0.8323
# Round: 7 | Client: client_2 training
# 1036/1036 [==============================] - 19s 19ms/step - loss: 0.2557 - accuracy: 0.8349 - recall: 0.8320 - precision: 0.8374 - f1_score: 0.8346
# Round: 7 | Client: client_3 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.2591 - accuracy: 0.8321 - recall: 0.8296 - precision: 0.8349 - f1_score: 0.8321
# Round: 7 | Client: client_9 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.2518 - accuracy: 0.8335 - recall: 0.8307 - precision: 0.8355 - f1_score: 0.8331
# Round: 7 | Client: client_10 training
# 1036/1036 [==============================] - 19s 19ms/step - loss: 0.2603 - accuracy: 0.8334 - recall: 0.8309 - precision: 0.8357 - f1_score: 0.8333
# Round: 7 | Client: client_8 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.2596 - accuracy: 0.8341 - recall: 0.8310 - precision: 0.8364 - f1_score: 0.8337
# Round: 7 | Client: client_4 training
# 1036/1036 [==============================] - 19s 19ms/step - loss: 0.2657 - accuracy: 0.8330 - recall: 0.8301 - precision: 0.8351 - f1_score: 0.8324
# Round: 7 | Client: client_6 training
# 1036/1036 [==============================] - 19s 19ms/step - loss: 0.2654 - accuracy: 0.8295 - recall: 0.8262 - precision: 0.8318 - f1_score: 0.8290
# 5177/5177 [==============================] - 20s 4ms/step
# comm_round: 7 | global_loss: 1.6942275762557983 | global_accuracy: 0.8494 | global_recall: 0.8494 | global_precision: 0.8495 | global_f1_score: 0.8494
#
# New Weights Saved
# Round: 8 | Client: client_6 training
# 1036/1036 [==============================] - 20s 19ms/step - loss: 0.2576 - accuracy: 0.8346 - recall: 0.8323 - precision: 0.8366 - f1_score: 0.8345
# Round: 8 | Client: client_7 training
# 1036/1036 [==============================] - 18s 17ms/step - loss: 0.2584 - accuracy: 0.8328 - recall: 0.8307 - precision: 0.8350 - f1_score: 0.8328
# Round: 8 | Client: client_2 training
# 1036/1036 [==============================] - 20s 19ms/step - loss: 0.2547 - accuracy: 0.8344 - recall: 0.8322 - precision: 0.8363 - f1_score: 0.8343
# Round: 8 | Client: client_3 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.2547 - accuracy: 0.8349 - recall: 0.8324 - precision: 0.8368 - f1_score: 0.8344
# Round: 8 | Client: client_8 training
# 1036/1036 [==============================] - 18s 18ms/step - loss: 0.2597 - accuracy: 0.8342 - recall: 0.8322 - precision: 0.8360 - f1_score: 0.8341
# Round: 8 | Client: client_1 training
# 1036/1036 [==============================] - 20s 19ms/step - loss: 0.2517 - accuracy: 0.8355 - recall: 0.8331 - precision: 0.8372 - f1_score: 0.8351
# Round: 8 | Client: client_4 training
# 1036/1036 [==============================] - 20s 19ms/step - loss: 0.2616 - accuracy: 0.8347 - recall: 0.8320 - precision: 0.8366 - f1_score: 0.8343
# Round: 8 | Client: client_10 training
# 1036/1036 [==============================] - 18s 18ms/step - loss: 0.2558 - accuracy: 0.8354 - recall: 0.8326 - precision: 0.8380 - f1_score: 0.8352
# Round: 8 | Client: client_5 training
# 1036/1036 [==============================] - 20s 19ms/step - loss: 0.2591 - accuracy: 0.8338 - recall: 0.8310 - precision: 0.8360 - f1_score: 0.8334
# Round: 8 | Client: client_9 training
# 1036/1036 [==============================] - 18s 18ms/step - loss: 0.2510 - accuracy: 0.8346 - recall: 0.8325 - precision: 0.8369 - f1_score: 0.8347
# 5177/5177 [==============================] - 21s 4ms/step
# comm_round: 8 | global_loss: 1.694889783859253 | global_accuracy: 0.8423 | global_recall: 0.8423 | global_precision: 0.8424 | global_f1_score: 0.8423
#
# Round: 9 | Client: client_2 training
# 1036/1036 [==============================] - 20s 19ms/step - loss: 0.2530 - accuracy: 0.8353 - recall: 0.8328 - precision: 0.8374 - f1_score: 0.8351
# Round: 9 | Client: client_5 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.2587 - accuracy: 0.8339 - recall: 0.8316 - precision: 0.8359 - f1_score: 0.8337
# Round: 9 | Client: client_1 training
# 1036/1036 [==============================] - 19s 19ms/step - loss: 0.2504 - accuracy: 0.8371 - recall: 0.8349 - precision: 0.8387 - f1_score: 0.8367
# Round: 9 | Client: client_10 training
# 1036/1036 [==============================] - 20s 19ms/step - loss: 0.2562 - accuracy: 0.8360 - recall: 0.8341 - precision: 0.8381 - f1_score: 0.8361
# Round: 9 | Client: client_9 training
# 1036/1036 [==============================] - 18s 17ms/step - loss: 0.2477 - accuracy: 0.8344 - recall: 0.8325 - precision: 0.8362 - f1_score: 0.8343
# Round: 9 | Client: client_7 training
# 1036/1036 [==============================] - 19s 19ms/step - loss: 0.2559 - accuracy: 0.8379 - recall: 0.8355 - precision: 0.8396 - f1_score: 0.8375
# Round: 9 | Client: client_8 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.2560 - accuracy: 0.8358 - recall: 0.8338 - precision: 0.8377 - f1_score: 0.8356
# Round: 9 | Client: client_6 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.2576 - accuracy: 0.8356 - recall: 0.8329 - precision: 0.8375 - f1_score: 0.8352
# Round: 9 | Client: client_4 training
# 1036/1036 [==============================] - 20s 19ms/step - loss: 0.2632 - accuracy: 0.8339 - recall: 0.8316 - precision: 0.8359 - f1_score: 0.8337
# Round: 9 | Client: client_3 training
# 1036/1036 [==============================] - 19s 18ms/step - loss: 0.2529 - accuracy: 0.8346 - recall: 0.8314 - precision: 0.8368 - f1_score: 0.8339
# 5177/5177 [==============================] - 21s 4ms/step
# comm_round: 9 | global_loss: 1.6967358589172363 | global_accuracy: 0.8435 | global_recall: 0.8434 | global_precision: 0.8437 | global_f1_score: 0.8436

# %%
global_model.load_weights("global_model_best_weights.h5")

# %%
loss, accuracy, precision, recall, f1_score = test_model(x_batch, y_batch, global_model, comm_round)
print("loss : ", loss.numpy())
print("accuracy : ", accuracy)
print("precision : ", precision)
print("recall : ", recall)
print("f1_score : ", f1_score)
# Out:
# 5177/5177 [==============================] - 20s 4ms/step
# comm_round: 9 | global_loss: 1.6942275762557983 | global_accuracy: 0.8494 | global_recall: 0.8494 | global_precision: 0.8495 | global_f1_score: 0.8494
#
# loss :  1.6942276
# accuracy :  0.8494494482408905
# precision :  0.84950006
# recall :  0.84937704
# f1_score :  0.8494384

# %%
for(x_batch, y_batch) in test_batched:
    logits = global_model.predict(x_batch)
    y_hat = np.argmax(logits, axis=1)
    y_true = np.argmax(y_batch, axis=1)
# Out:
# 5177/5177 [==============================] - 20s 4ms/step

# %%
from sklearn.metrics import accuracy_score, precision_recall_fscore_support,confusion_matrix, classification_report, precision_score, recall_score
from sklearn.metrics import f1_score as f1_score_rep
import seaborn as sn


def print_score(y_pred, y_real, label_encoder):
    print("Accuracy: ", accuracy_score(y_real, y_pred))
    print("Precision:: ", precision_score(y_real, y_pred, average="micro"))
    print("Recall:: ", recall_score(y_real, y_pred, average="micro"))
    print("F1_Score:: ", f1_score_rep(y_real, y_pred, average="micro"))

    print()
    print("Macro precision_recall_fscore_support (macro) average")
    print(precision_recall_fscore_support(y_real, y_pred, average="macro"))

    print()
    print("Macro precision_recall_fscore_support (micro) average")
    print(precision_recall_fscore_support(y_real, y_pred, average="micro"))

    print()
    print("Macro precision_recall_fscore_support (weighted) average")
    print(precision_recall_fscore_support(y_real, y_pred, average="weighted"))
    
    print()
    print("Confusion Matrix")
    cm = confusion_matrix(y_real, y_pred)
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    df_cm = pd.DataFrame(cm, index = [i for i in label_encoder.classes_],
                  columns = [i for i in label_encoder.classes_])
    plt.figure(figsize = (10,7))
    sn.heatmap(df_cm, annot=True)

    print()
    print("Classification Report")
    print(classification_report(y_real, y_pred, target_names=label_encoder.classes_))

# %%
from sklearn.metrics import roc_curve, auc
from itertools import cycle

def ROC_plot(y_true_ohe, y_hat_ohe, label_encoder, n_classes):    
    lw = 2
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(y_true_ohe[:, i], y_hat_ohe[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])
                                  
    all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

    mean_tpr = np.zeros_like(all_fpr)
    for i in range(n_classes):
        mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

    mean_tpr /= n_classes
    fpr["macro"] = all_fpr
    tpr["macro"] = mean_tpr
    roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

    fpr["micro"], tpr["micro"], _ = roc_curve(y_true_ohe.ravel(), y_hat_ohe.ravel())
    roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])
    
    plt.figure(figsize=(20,20))
    plt.plot(
        fpr["micro"],
        tpr["micro"],
        label="micro-average ROC curve (area = {0:0.2f})".format(roc_auc["micro"]),
        color="deeppink",
        linestyle=":",
        linewidth=4,
    )

    plt.plot(
        fpr["macro"],
        tpr["macro"],
        label="macro-average ROC curve (area = {0:0.2f})".format(roc_auc["macro"]),
        color="navy",
        linestyle=":",
        linewidth=4,
    )

    colors = cycle(["aqua", "darkorange", "cornflowerblue"])
    for i, color in zip(range(n_classes), colors):
        plt.plot(
            fpr[i],
            tpr[i],
            color=color,
            lw=lw,
            label="ROC curve of class {0} (area = {1:0.2f})".format(label_encoder.classes_[i], roc_auc[i]))

    plt.plot([0, 1], [0, 1], "k--", lw=lw)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title("multiclass characteristic")
    plt.legend(loc="lower right")
    plt.show()

# %%
y_true_ohe = to_categorical(y_true, num_classes=len(label_encoder.classes_))
y_hat_ohe =  to_categorical(y_hat, num_classes=len(label_encoder.classes_))

# %%
ROC_plot(y_true_ohe, y_hat_ohe, label_encoder, len(label_encoder.classes_))

# %%
print_score(y_hat, y_true, label_encoder)
# Out:
# Accuracy:  0.8494494482408905
# Precision::  0.8494494482408905
# Recall::  0.8494494482408905
# F1_Score::  0.8494494482408905
#
# Macro precision_recall_fscore_support (macro) average
# (0.8199136170708067, 0.8667358509840362, 0.8356350947139649, None)
#
# Macro precision_recall_fscore_support (micro) average
# (0.8494494482408905, 0.8494494482408905, 0.8494494482408905, None)
#
# Macro precision_recall_fscore_support (weighted) average
# (0.7869202098945549, 0.8494494482408905, 0.8076330977663587, None)
#
# Confusion Matrix
#
# Classification Report
#                 precision    recall  f1-score   support
#
#         benign       1.00      1.00      1.00     12431
#   gafgyt_combo       0.86      0.83      0.84     12276
#    gafgyt_junk       0.68      0.72      0.70      6180
#    gafgyt_scan       1.00      1.00      1.00      5859
#     gafgyt_tcp       0.00      0.00      0.00     20902
#     gafgyt_udp       0.50      1.00      0.66     20802
#      mirai_ack       0.99      1.00      1.00     12111
#     mirai_scan       1.00      1.00      1.00     19356
#      mirai_syn       1.00      1.00      1.00     13149
#      mirai_udp       1.00      1.00      1.00     31250
# mirai_udpplain       1.00      0.99      1.00     11336
#
#       accuracy                           0.85    165652
#      macro avg       0.82      0.87      0.84    165652
#   weighted avg       0.79      0.85      0.81    165652

# %%
figure, axis = plt.subplots(3, 2, figsize=(15, 15))

axis[0, 0].plot(global_loss)
axis[0, 0].set_title("global loss")
  
axis[0, 1].plot(global_accuracy)
axis[0, 1].set_title("global accuracy")
  
axis[1, 0].plot(global_precision)
axis[1, 0].set_title("global precision")
  
axis[1, 1].plot(global_recall)
axis[1, 1].set_title("global recall")

axis[2, 0].plot(global_f1)
axis[2, 0].set_title("global f1 score")
  
plt.show()
