# %% [markdown]
# # 0.1 data aurmentation on 50% of nodes

# %%
# importing package
import matplotlib.pyplot as plt
  
# create data
global_f1 = [0.643026, 0.8339904, 0.6551356, 0.84389746, 0.8560483, 0.8056145, 0.7999444, 0.86313224, 0.8570583, 0.7237207]
global_accuracy = [0.6462946417791515, 0.8341160988095525, 0.6552048873542125, 0.8438895998840944, 0.8560234708907831, 0.8056165938231956, 0.7999963779489532, 0.8631408011976915, 0.857061792190858, 0.7237280564074083]

global_f1_small = [0.6449744, 0.83505297, 0.663122, 0.84741455, 0.8614682, 0.80898714, 0.79591966, 0.8646837, 0.85705227, 0.72195905]
global_accuracy_small = [0.6477313886943713, 0.8351966773718398, 0.6632216936710694, 0.8474875039238886, 0.8614565474609422, 0.8090092483036727, 0.7959396807765677, 0.8646801728925699, 0.8570557554391133, 0.7219592881462342]
  
# plot lines
plt.plot( range(len(global_f1)), global_f1, label = "global_f1")
plt.plot(range(len(global_f1_small)), global_f1_small, label = "global_f1_small")

plt.legend()
plt.show()

# %%
# plot lines
plt.plot( range(len(global_accuracy)), global_accuracy, label = "global_accuracy")
plt.plot(range(len(global_accuracy_small)), global_accuracy_small, label = "global_accuracy_small")

plt.legend()
plt.show()

# %%
global_f1 = [0.8103501, 0.83138394, 0.83738196, 0.83853126, 0.8398294, 0.85489446, 0.8504693, 0.8610342, 0.8680788, 0.8667996]
global_f1_small = [0.80196613, 0.8243766, 0.82928675, 0.83611614, 0.8403799, 0.8440559, 0.8589401, 0.86128616, 0.8646639, 0.86196625]

plt.plot( range(len(global_f1)), global_f1, label = "global_f1")
plt.plot(range(len(global_f1_small)), global_f1_small, label = "global_f1_small")

plt.legend()
plt.show()

# %%
# learning rate to 3e-2

# %%
global_f1 = [0.6464119, 0.8246471, 0.8317545, 0.8360817, 0.8398392]
global_f1_small = [0.8126583, 0.8240415, 0.8235119, 0.8335074, 0.8260312]

plt.plot( range(len(global_f1)), global_f1, label = "global_f1")
plt.plot(range(len(global_f1_small)), global_f1_small, label = "global_f1_small")

plt.legend()
plt.show()

# %%
global_f1 = [0.796171, 0.84767383, 0.8450753, 0.8422577, 0.8525026]
global_f1_small = [0.7870423, 0.82869124, 0.84779215, 0.8198086, 0.8415164]

plt.plot( range(len(global_f1)), global_f1, label = "global_f1")
plt.plot(range(len(global_f1_small)), global_f1_small, label = "global_f1_small")

plt.legend()
plt.show()

# %%
# learning rate to 3e-2

# %%
global_f1 = [0.79792184, 0.83032405, 0.8383054, 0.83924747, 0.8410398]
global_f1_small = [0.8056421, 0.82905185, 0.835121, 0.80929327, 0.840641]

plt.plot( range(len(global_f1)), global_f1, label = "global_f1")
plt.plot(range(len(global_f1_small)), global_f1_small, label = "global_f1_small")

plt.legend()
plt.show()

# %%
import tensorflow as tf

l1 = [90, 7, 30, 6]
l2 = [8,  2, 40, 5]

l3 = [l1, l2]

for tuple in zip(*l3):
    print(tuple)

new = [tf.math.reduce_sum(tuple) for tuple in zip(*l3)]
new
# Out:
# 2023-04-06 11:03:05.105694: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-04-06 11:03:05.257900: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-06 11:03:05.953283: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# (90, 8)
# (7, 2)
# (30, 40)
# (6, 5)
# ...

# %%
global_f1 = [0.6763939, 0.751689, 0.7705521, 0.7828001, 0.79557043, 0.7950315, 0.8047221, 0.813224, 0.815173, 0.8116225, 0.8226225, 0.82694644, 0.82179147, 0.82499075, 0.83154887]
global_f1_small = [0.26247928, 0.64422023, 0.71686506, 0.7275182, 0.77248853, 0.790574, 0.76981133, 0.81038606, 0.8148753, 0.81971484, 0.82293075, 0.8275684, 0.8257809, 0.8276759, 0.83037364]

plt.plot( range(len(global_f1)), global_f1, label = "global_f1")
plt.plot(range(len(global_f1_small)), global_f1_small, label = "global_f1_small")

plt.legend()
plt.show()
