# %%
import pandas as pd

df = pd.read_pickle("./data/df.pkl")
df["type"].value_counts()
# Out:
# mirai_udp         156248
# gafgyt_tcp        104510
# gafgyt_udp        104011
# mirai_scan         96781
# mirai_syn          65746
# benign             62154
# gafgyt_combo       61380
# mirai_ack          60554
# mirai_udpplain     56681
# gafgyt_junk        30898
# gafgyt_scan        29297
# Name: type, dtype: int64

# %%
df[df["type"] == "gafgyt_scan"]
# Out:
#         MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  \
# 310680          1.000000       98.000000        0.000000e+00
# 310681          1.027124       98.000000        1.818989e-12
# 310682          1.029968       98.000000        0.000000e+00
# 310683          1.338152       74.086423        1.933753e+02
# 310684          2.311785       74.049039        1.097295e+02
# ...                  ...             ...                 ...
# 339972         36.296570       74.171321        4.432312e+00
# 339973         37.295550       74.166728        4.314235e+00
# 339974         37.507012       74.162283        4.199932e+00
# 339975         38.272212       74.158042        4.090863e+00
# 339976         39.270884       74.154018        3.987313e+00
#
#         MI_dir_L3_weight  MI_dir_L3_mean  MI_dir_L3_variance  \
# 310680          1.000000       98.000000        0.000000e+00
# 310681          1.114820       98.000000        1.818989e-12
# ...

# %%
df[df["type"] == "gafgyt_scan"]["type"].value_counts()
# Out:
# gafgyt_scan    29297
# Name: type, dtype: int64

# %%
# ------------------------ quelli che non hanno i casi rari

# %%
df[df["type"] != "gafgyt_scan"]
# Out:
#         MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  \
# 0               1.000000       60.000000            0.000000
# 1               1.000000      590.000000            0.000000
# 2               1.942585      590.000000            0.000000
# 3               1.000000       60.000000            0.000000
# 4               1.979600       66.061831           35.996177
# ...                  ...             ...                 ...
# 828255         87.531184      215.656970        52663.369508
# 828256         88.530533      219.478736        53346.970597
# 828257         89.031218      223.236084        53990.571728
# 828258         90.030923      221.422973        53683.560352
# 828259         91.030328      219.649685        53376.932506
#
#         MI_dir_L3_weight  MI_dir_L3_mean  MI_dir_L3_variance  \
# 0               1.000000       60.000000        0.000000e+00
# 1               1.000000      590.000000        0.000000e+00
# ...

# %%
df[df["type"] != "gafgyt_scan"]["type"].value_counts()
# Out:
# mirai_udp         156248
# gafgyt_tcp        104510
# gafgyt_udp        104011
# mirai_scan         96781
# mirai_syn          65746
# benign             62154
# gafgyt_combo       61380
# mirai_ack          60554
# mirai_udpplain     56681
# gafgyt_junk        30898
# Name: type, dtype: int64
